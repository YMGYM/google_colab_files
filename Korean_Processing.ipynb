# %% [markdown]
# <a href="https://colab.research.google.com/github/YMGYM/google_colab_files/blob/master/Korean_Processing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction
#
# 이 파일은 딥러닝 네트워크로 한국어 언어 처리를 연습해보기 위한 파일입니다.

# %% [markdown]
# # import
# 필요한 파일, 라이브러리를 임포트합니다.
# [AI HUB](https://aihub.or.kr/keti_data_board/language_intelligence) 데이터셋을 사용했습니다.

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import tensorflow.keras as K
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/content/drive/My Drive/Datasets/preprocessed_twitter_dialog_korean_dataset.csv')
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (81,82,83,84,85,86,87,88,89,90,91,92,93,94,95,96,97,98,99,100,101,102,103,104,105,106,107,108,109,110,111,112,113,114,115,116,117,118,119,120,121,122,123,124,125,126,127,128,129,130,131,132,133,134,135,136,137,138,139,140,141,142,143,144,145,146,147,148,149,150,151,152,153,154,155,156,157,158,159,160,161,162,163,164,165,166,167,168,169,170,171,172,173,174,175,176,177,178,179,180,181,182,183,184,185,186,187,188,189,190,191,192,193,194,195,196,197,198,199,200,201,202,203,204,205,206,207,208,209,210,211,212,213,214,215,216,217,218,219,220,221,222,223,224,225,226,227,228,229,230,231,232,233,234,235,236,237,238,239,240,241,242,243,244,245,246,247,248,249,250,251,252,253,254,255,256,257,258,259,260,261,262,263,264,265,266,267,268,269,270,271,272,273,274,275,276,277,278,279,280,281,282,283,284,285,286,287,288,289,290,291,292,293,294,295,296,297,298,299,300,301,302,303,304,305,306,307,308,309,310,311,312,313,314,315,316,317,318,319,320,321,322,323,324,325,326,327,328,329,330,331,332,333,334,335,336,337,338,339,340,341,342,343,344,345,346,347,348,349,350,351,352,353,354,355,356,357,358,359,360,361,362,363,364,365,366,367,368,369,370,371,372,373,374,375,376,377,378,379,380,381,382,383,384,385,386,387,388,389,390,391,392,393,394,395,396,397,398,399,400,401,402,403,404) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
dropped_data = data.drop(labels='Unnamed: 0', axis=1)

# %%
dropped_data
# Out:
#          0    1    2   3   4     5    6  ...  397  398  399  400  401  402  403
# 0      기계식  키보드    쓰   어   보     고    싶  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1        쌓    ㄴ    것   도   많    던데    쓰  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2        쌓    ㄴ    것   도   있    나요    ?  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3       이거    쓰   는데  예쁘   고  딸깍거리   어요  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4        우    와   진짜  예쁘  어요     .  NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...    ...  ...  ...  ..  ..   ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 13586    나   아도   고민   중   이    ㄴ데   가게  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 13587    좋   아요    .   그   때     는    돈  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 13588    좋    은  아파트   에   살     려    는  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 13589  개인적   으로   주차  공간   이    주택   이나  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 13590    그   부분    도   크   ㄴ    장점    이  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [13591 rows x 404 columns]

# %%
class Tokenizer:
  def __init__(self):
    self.word2idx = {}
    self.idx2word = {}

  def make_word_index(self, data):
    for vocab in data:
      if vocab == np.nan:
        continue
      if self.word2idx.get(vocab) == None: # get을 쓰지 않으면 Null 키 오류
        self.word2idx[vocab] = len(self.word2idx)
        self.idx2word[len(self.idx2word)] = vocab
  
  def get_data(self):
    return self.word2idx, self.idx2word

  def get_word(self, sent):
    result = np.array([],dtype="int16")
    for idx in sent:
      result = np.hstack([result, self.idx2word.get(idx)])
    return result

  def get_idx(self, sent):
    sent = sent.dropna()
    result = np.array([],dtype="int16")
    for word in sent:
      result = np.hstack([result, self.word2idx.get(word)])
    return result

# %%
tokenizer = Tokenizer()

# %%
for idx, row in dropped_data.iterrows():
  tokenizer.make_word_index(row.dropna())

# %%
len(tokenizer.idx2word)
# Out:
# 10034

# %%
sent = dropped_data.iloc[1]
result = tokenizer.get_idx(sent)
result
# Out:
# array([ 9, 10, 11, 12, 13, 14,  2,  3,  4, 15,  8, 16, 17, 18,  8])

# %%
result2 = tokenizer.get_word(result)
result2
# Out:
# array(['쌓', 'ㄴ', '것', '도', '많', '던데', '쓰', '어', '보', '세요', '.', '정말', '좋',
#        '아요', '.'], dtype='<U6')

# %%
for r in result:
  print(tokenizer.idx2word.get(r))
# Out:
# 쌓
# ㄴ
# 것
# 도
# 많
# 던데
# 쓰
# 어
# 보
# 세요
# .
# 정말
# 좋
# 아요
# .

# %%
K.preprocessing.sequence.pad_sequences()

# %%
# model = K.sequential()
# model.add(K.layers.LSTM(128))
